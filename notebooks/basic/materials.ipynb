# %% [markdown]
# # GEMC in Binder
# <hr style="height:4px;border:0;background:#4a90e2;">
#
# <br/>
# Welcome! This notebook runs GEMC directly in your browser.
# How to use:
#
# 1. Click any grey code cell to select it
# 2. Press `Shift + Enter` to run it (or click ▶ in the toolbar)
# 3. Run cells in order, top to bottom
# 4. Wait for `In [*]` to become `In [1]` before running the next cell
#
# <br/>
#
# ## Example: materials → [documentation](https://gemc.github.io/home/examples/basic/materials).
#
# <hr style="height:2px;border:0;background:#4a90e2;">
#
# <br/>
#
# This example demonstrates Geant4 built-in materials, custom molecular and fractional-mass materials, and optical material properties.
#
# <br/>

# %%
# ┌───────────────────────────────────────────────────┐
# │  Cell 1 · Environment Setup (Shift+Enter to run)  │
# │  import PyVista and editor                        │
# │  Copy basic/material example to local directory   │
# └───────────────────────────────────────────────────┘

import subprocess, warnings, sys, vtk
import pyvista as pv
vtk.vtkObject.GlobalWarningDisplayOff()  # suppress warnings

from run_geometry import run_geometry
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from notebook_tools import edit, setup_example
setup_example("examples/basic/material")

# %%
# ┌─────────────────────────────────────────────────────────────┐
# │  Optional: Cell 2 · Edit materials.py (Shift+Enter to run)  │
# └─────────────────────────────────────────────────────────────┘

edit("materials.py")

# %%
# ┌──────────────────────────────────────────────────────────┐
# │  Cell 3 · Build materials detector (Shift+Enter to run)  │
# │                                                          │
# │  The geometry is rendered by PyVista in Jupyter.         │
# │  Use the mouse to zoom/rotatoe/shift the view.           │
# └──────────────────────────────────────────────────────────┘

run_geometry("materials.py")

# %%
# ┌────────────────────────────────────────────────────────────┐
# │  Cell 4 · Run 100 events in GEMC (Shift+Enter to run)      │
# │                                                            │
# │  - Load materials gsystem                                  │
# │  - Write CSV, ROOT outputs                                 │
# │  - Display generated screenshot if present                 │
# └────────────────────────────────────────────────────────────┘

from pathlib import Path
from IPython.display import Image, display

yaml='materials.yaml'
driver='-g4view=[{driver: TOOLSSG_OFFSCREEN}]'
camera='-g4camera=[{phi: -10*deg, theta: 250*deg}]'
light='-g4light=[{phi: 160*deg, theta: 120*deg}]'
nevents="-n=100"
nthreads="-nthreads=1"

result = subprocess.run(["gemc", yaml, driver, camera, light, nevents, nthreads], capture_output=True, text=True)
if result.returncode != 0:
    print("GEMC failed:")
    print(result.stderr)
else:
    print(result.stdout)

image_file = Path("gemc_run_0.png")
if image_file.exists():
    display(Image(filename=str(image_file)))
else:
    print(f"No GEMC image found: {image_file}")
    
    
result = subprocess.run(
	["ls", "-l"],
	capture_output=True,
	text=True,
)

print(result.stdout)

# %%
# ┌──────────────────────────────────────────────────────────────────┐
# │  Optional: Cell 5 · Edit materials.yaml (Shift+Enter to run)     │
# │                                                                  │
# │  Edit the YAML file to change generator, variation, output, etc. │
# └──────────────────────────────────────────────────────────────────┘

edit("materials.yaml")

# %% [markdown]
# ### Cell 6 · Plot totEdep (Shift+Enter to run)
#
# Use the analyzer API on the digitized CSV file with a log-scale 50-bin histogram.

# %%
from analyzer import read_output, plot_variable; plot_variable(read_output("material_t0_digitized.csv"), "totEdep", data="digitized", bins=50, logy=True, show=True)

# %% [markdown]
# ### Cell 7 · Plot E (Shift+Enter to run)
#
# Use the analyzer API on the digitized CSV file with a log-scale 50-bin histogram.

# %%
from analyzer import read_output, plot_variable; plot_variable(read_output("material_t0_digitized.csv"), "E", data="digitized", bins=50, logy=True, show=True)
