# %% [markdown]
# # GEMC in Binder
# <hr style="height:4px;border:0;background:#4a90e2;">
#
# <br/>
# Welcome! This notebook runs GEMC directly in your browser.
# How to use:
#
# 1. Click any grey code cell to select it
# 2. Press `Shift + Enter` to run it (or click ▶ in the toolbar)
# 3. Run cells in order, top to bottom
# 4. Wait for `In [*]` to become `In [1]` before running the next cell
#
# <br/>
#
# > Some optional cells are provided to edit the code and the YAML files. After editing,
# > re-run the other cells to see the changes.
#
# <br/>
#
# ## Example: b2 → [documentation](https://gemc.github.io/home/examples/basic/b2).
#
# <hr style="height:2px;border:0;background:#4a90e2;">
#
# <br/>
#
# This example duplicates the geant4 basic example B2. It uses the **flux digitization** to save true and digitized information in the output.
#
# <br/>

# %% [markdown]
# ### Cell 1 · Environment Setup (Shift+Enter to run)
#
# import PyVista and editor
# Copy basic/b2 example to local directory

# %%
import subprocess, warnings, sys, vtk
import pyvista as pv
vtk.vtkObject.GlobalWarningDisplayOff()  # suppress warnings

from run_geometry import run_geometry
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from notebook_tools import edit, setup_example
setup_example("examples/basic/b2")

# %% [markdown]
# ### Optional: Cell 2 · Edit b2.py (Shift+Enter to run)

# %%
edit("b2.py")

# %% [markdown]
# ### Cell 3 · Build b2 detector (Shift+Enter to run)
#
# The geometry is rendered by PyVista in Jupyter.
# Use the mouse to zoom/rotatoe/shift the view.

# %%
run_geometry("b2.py")

# %% [markdown]
# ### Cell 4 · Run 1000 events in GEMC (Shift+Enter to run)
#
# - Load b2 gsystem
# - Write CSV, ROOT outputs
# - Display generated screenshot if present

# %%
from pathlib import Path
from IPython.display import Image, display

yaml='b2.yaml'
driver='-g4view=[{driver: TOOLSSG_OFFSCREEN}]'
camera='-g4camera=[{phi: -10*deg, theta: 250*deg}]'
light='-g4light=[{phi: 160*deg, theta: 120*deg}]'
nevents="-n=1000"
nthreads="-nthreads=1"

result = subprocess.run(["gemc", yaml, driver, camera, light, nevents, nthreads], capture_output=True, text=True)
if result.returncode != 0:
    print("GEMC failed:")
    print(result.stderr)
else:
    print(result.stdout)

image_file = Path("gemc_run_0.png")
if image_file.exists():
    display(Image(filename=str(image_file)))
else:
    print(f"No GEMC image found: {image_file}")
    
    
result = subprocess.run(
	["ls", "-l"],
	capture_output=True,
	text=True,
)

print(result.stdout)

# %% [markdown]
# ### Optional: Cell 5 · Edit b2.yaml (Shift+Enter to run)
#
# Edit the YAML file to change generator, variation, output, etc.

# %%
edit("b2.yaml")

# %% [markdown]
# ### Cell 6 · Plot totEdep (Shift+Enter to run)
#
# Use the analyzer API on the digitized CSV file with a linear 50-bin histogram.

# %%
from analyzer import read_output, plot_variable; plot_variable(read_output("CO2_t0_digitized.csv"), "totEdep", data="digitized", bins=50, logy=False, show=True)

# %% [markdown]
# ### Cell 7 · Plot true-info vz (Shift+Enter to run)
#
# Use the analyzer API on the true-info CSV file with a linear 50-bin histogram.

# %%
from analyzer import read_output, plot_variable; plot_variable(read_output("CO2_t0_true_info.csv"), "vz", data="true_info", bins=50, logy=False, show=True)
