# %%
# Cell 1 — verify GEMC is available
import subprocess, sys

result = subprocess.run(["gemc", "--version"], capture_output=True, text=True)
print("GEMC version:", result.stdout.strip())
# Out:
# GEMC version: *******************************************************************
#  gemc  version: dev
#  Called from: .
#  Install: /cvmfs/oasis.opensciencegrid.org/geant4/g4install/ubuntu24-gcc13-arm64/gemc/dev/bin
#  Released on: 2026-05-01
#  GEMC Reference: Nucl. Instrum. Meth. A, Volume 959, 163422 (2020)
#  GEMC Homepage: https://gemc.github.io/home
#  Author: Maurizio Ungaro, ungaro@jlab.org
#
# *******************************************************************
