# %%
# ┌────────────────────────────────────────────────────────────────────────┐
# │  Cell 1 · Environment Setup (Shift+Enter to run)                       │
# │                                                                        │
# │  Welcome! This notebook runs GEMC directly in your browser.            │
# │  How to use:                                                           │
# │                                                                        │
# │  1. Click any grey code cell to select it                              │
# │  2. Press `Shift + Enter` to run it (or click Run in the toolbar)      │
# │  3. Run cells in order, top to bottom                                  │
# │  4. Wait for `In [*]` to become `In [1]` before running the next cell  │
# │                                                                        │
# │  Optional cells are provided to edit the code and the YAML files.      │
# │  After editing, re-run the other cells to see the changes.             │
# │                                                                        │
# │  Example: cherenkov -> documentation:                                  │
# │  https://gemc.github.io/home/examples/optical/cherenkov.               │
# │                                                                        │
# │  This example showcases the activation of the Cherenkov radiation in   │
# │  a GEMC detector.                                                      │
# │                                                                        │
# │                                                                        │
# │  Import notebook helpers                                               │
# │  Copy optical/cherenkov example to local directory                     │
# └────────────────────────────────────────────────────────────────────────┘

import subprocess
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))
from notebook_tools import edit, setup_example, run_gemc_display

from pygemc.api.run_geometry import run_geometry
setup_example("examples/optical/cherenkov")

# %%
# ┌──────────────────────────────────────────────────────────┐
# │  Cell 2 · Build cherenkov detector (Shift+Enter to run)  │
# │                                                          │
# │  The geometry is rendered by PyVista in Jupyter.         │
# │  Use the mouse to zoom/rotate/shift the view.            │
# │  You can edit this file later; see cells below.          │
# └──────────────────────────────────────────────────────────┘

print(Path("cherenkov.py").read_text())
run_geometry("cherenkov.py")

# %%
# ┌─────────────────────────────────────────────────────────┐
# │  Cell 3 · Run 100 events in GEMC (Shift+Enter to run)   │
# │                                                         │
# │  - Load cherenkov gsystem                               │
# │  - Write CSV, ROOT outputs                              │
# │  - Display generated screenshot if present              │
# │                                                         │
# │  If GEMC crashes, just re-run this cell.                │
# └─────────────────────────────────────────────────────────┘

yaml='cherenkov.yaml'
driver='-g4view=[{driver: TOOLSSG_OFFSCREEN}]'
camera='-g4camera=[{phi: -10*deg, theta: 250*deg}]'
light='-g4light=[{phi: 160*deg, theta: 120*deg}]'
nevents="-n=1"
nthreads="-nthreads=1"

result = subprocess.run(["gemc", yaml, driver, camera, light, nevents, nthreads], capture_output=True, text=True)
run_gemc_display(result)

# %%
# ┌───────────────────────────────────────────────────────────────────────┐
# │  Cell 4 · Plot E (Shift+Enter to run)                                 │
# │                                                                       │
# │  Use the analyzer API on the digitized CSV file with a linear 50-bin  │
# │  histogram.                                                           │
# └───────────────────────────────────────────────────────────────────────┘

from pygemc import read_output, plot_variable
plot_variable(read_output("cherenkov_t0_digitized.csv"), "E", bins=50, logy=True, show=True)

# %%
# ┌───────────────────────────────────────────────────────────────────────┐
# │  Cell 5 · Plot time (Shift+Enter to run)                              │
# │                                                                       │
# │  Use the analyzer API on the digitized CSV file with a linear 50-bin  │
# │  histogram.                                                           │
# └───────────────────────────────────────────────────────────────────────┘

from pygemc import read_output, plot_variable
plot_variable(read_output("cherenkov_t0_digitized.csv"), "time", bins=50, logy=False, show=True)

# %%
# ┌────────────────────────────────────────────────────────────────────────┐
# │  Cell 6 · Plot panel identifier (Shift+Enter to run)                   │
# │                                                                        │
# │  Use the analyzer API on the digitized CSV file with a linear 50-bin   │
# │  histogram to see which panels were hit.                               │
# └────────────────────────────────────────────────────────────────────────┘

from pygemc import read_output, plot_variable
plot_variable(read_output("cherenkov_t0_digitized.csv"), "panel", bins=50, logy=False, show=True)

# %%
# ┌─────────────────────────────────────────────────────────────┐
# │  Optional: Cell 7 · Edit cherenkov.py (Shift+Enter to run)  │
# └─────────────────────────────────────────────────────────────┘

edit("cherenkov.py")

# %%
# ┌───────────────────────────────────────────────────────────────────┐
# │  Optional: Cell 8 · Edit cherenkov.yaml (Shift+Enter to run)      │
# │                                                                   │
# │  Edit the YAML file to change generator, variation, output, etc.  │
# └───────────────────────────────────────────────────────────────────┘

edit("cherenkov.yaml")
